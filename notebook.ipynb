# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('DATA\lifeexpectancydata.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   country                          2938 non-null   object
#  1   year                             2938 non-null   int64
#  2   status                           2938 non-null   object
#  3   life expectancy                  2928 non-null   float64
#  4   adult mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   hepatitis b                      2385 non-null   float64
#  9   measles                          2938 non-null   int64
#  10  bmi                              2904 non-null   float64
#  11  polio                            2919 non-null   float64
# ...

# %%
Afghanistan = df[df['Country']=='Afghanistan'] 
df.groupby(['Year'])[['Life expectancy', 'Adult Mortality',
       'infant deaths','under-five deaths']].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
filtered_df = df[df['Country'].isin(['United Arab Emirates','United Kingdom of Great Britain and Northern Ireland'])]
filtered_df.groupby('Year')[['Alcohol','Life expectancy']].mean().loc[2000]
# Out:
# Alcohol             6.115
# Life expectancy    76.000
# Name: 2000, dtype: float64

# %%
df[['percentage expenditure','Adult Mortality']].corr()
# Out:
#                         percentage expenditure  Adult Mortality
# percentage expenditure                 1.00000         -0.24286
# Adult Mortality                       -0.24286          1.00000

# %%
developed=df[df['status']=='developed']
developing = df[df['status']=='developing']
# Out:
#           country  year      status  life expectancy  adult mortality  \
# 0     afghanistan  2015  developing             65.0            263.0
# 1     afghanistan  2014  developing             59.9            271.0
# 2     afghanistan  2013  developing             59.9            268.0
# 3     afghanistan  2012  developing             59.5            272.0
# 4     afghanistan  2011  developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     zimbabwe  2004  developing             44.3            723.0
# 2934     zimbabwe  2003  developing             44.5            715.0
# 2935     zimbabwe  2002  developing             44.8             73.0
# 2936     zimbabwe  2001  developing             45.3            686.0
# 2937     zimbabwe  2000  developing             46.0            665.0
#
#       infant deaths  alcohol  percentage expenditure  hepatitis b  measles  \
# ...

# %%
developing_country = df[df['status']=='developing']
avg_mortality = developing_country.groupby('year')[['adult mortality','percentage expenditure']].mean().reset_index()
avg_mortality
# Out:
#     year  adult mortality  percentage expenditure
# 0   2000       200.496689              172.127397
# 1   2001       193.158940              193.352604
# 2   2002       189.443709              208.719722
# 3   2003       187.609272              274.811662
# 4   2004       207.834437              308.140430
# 5   2005       184.172185              371.449443
# 6   2006       186.695364              261.189536
# 7   2007       177.589404              347.608217
# 8   2008       195.172185              420.268478
# 9   2009       181.754967              319.873865
# 10  2010       180.370861              354.663502
# 11  2011       175.788079              371.690281
# 12  2012       165.258278              564.080343
# 13  2013       166.165563              483.984081
# 14  2014       164.430464              510.045841
# 15  2015       169.390728                2.889105

# %%
corr_mortality_expenditure = developing_country.groupby('year')[['adult mortality','percentage expenditure']].corr().reset_index()
corr_mortality_expenditure
# Out:
#     year                 level_1  adult mortality  percentage expenditure
# 0   2000         adult mortality         1.000000               -0.204244
# 1   2000  percentage expenditure        -0.204244                1.000000
# 2   2001         adult mortality         1.000000               -0.271592
# 3   2001  percentage expenditure        -0.271592                1.000000
# 4   2002         adult mortality         1.000000               -0.232167
# 5   2002  percentage expenditure        -0.232167                1.000000
# 6   2003         adult mortality         1.000000               -0.201693
# 7   2003  percentage expenditure        -0.201693                1.000000
# 8   2004         adult mortality         1.000000               -0.250672
# 9   2004  percentage expenditure        -0.250672                1.000000
# 10  2005         adult mortality         1.000000               -0.200340
# 11  2005  percentage expenditure        -0.200340                1.000000
# ...

# %%
df.groupby('year')['population'].agg('sum').reset_index()
# Out:
#     year    population
# 0   2000  4.145742e+09
# 1   2001  4.255115e+09
# 2   2002  4.111145e+09
# 3   2003  3.912207e+09
# 4   2004  3.706598e+09
# 5   2005  3.951491e+09
# 6   2006  3.508473e+09
# 7   2007  3.967115e+09
# 8   2008  3.757510e+09
# 9   2009  3.729857e+09
# 10  2010  4.254391e+09
# 11  2011  4.081799e+09
# 12  2012  4.272569e+09
# 13  2013  4.287227e+09
# 14  2014  4.355075e+09
# 15  2015  4.340917e+09

# %%
usa_bmi = df[df['country'] == 'united states of america']['bmi']
year = df[df['country'] == 'united states of america']['year']


plt.plot(year,usa_bmi ,  marker='o' )
plt.title('indice de masse corporel (USA)')
plt.xlabel('année')
plt.ylabel('indice ')
plt.legend()
plt.grid(True)

# Afficher le graphe
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
